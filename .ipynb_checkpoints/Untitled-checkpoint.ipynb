# %%
import pandas as pd

# %%
d = [{'Turma': 'Informática Básica 1º ano B', 'Ana Julia Duarte Porto': 'N', 'Antônio Henrique Pereira Santos': 'N', 'Breno Ryan Costa da Silva': 'N', 'Bruna Ariardyne de Souza Barbosa': 'N', 'Cristiana dos Santos Pereira': 'F', 'Daniele Ezequiel de Jesus': 'F', 'Ellen Brenda Alves da Silva': 'F', 'Emanuelle Beatriz da Silva Venâncio': 'F', 'Gabriela do Nascimento Monteiro': 'P', 'Gisele de Souza Mendonca': 'P', 'Jefferson Breno Feitosa de Lima': 'P', 'Joao Vitor Matias Camara': 'N', 'Kelly Mirelly Firmino Diniz': 'N', 'Lays Danielle dos Santos Targino': 'N', 'Maria Gabriele Santos Benjamim': 'N', 'Mirela Felix dos Santos': 'F', 'Mirele dos Santos Lira': 'F', 'Pedro Henrique Guedes Costa Garcia': 'F', 'Rikelme de Oliveira Fernandes': 'F', 'Sandy Ashley Cirne Eloy': 'N', 'Sarah Priscila Nunes Marques': 'N', 'Sarah Soares de Araújo': 'N', 'Thalia de Oliveira Fernandes': 'N', 'Thayna Galdino Câmara Dantas': 'F', 'Valessa Bezerra Fernandes': 'N', 'Vinicius Araujo Amancio Gomes': 'N', 'Yago Alves Santos': 'N'}]

# %%
def getItemsDict(dicionario):
    
    keys = []
    values = []
    
    for k, v in dicionario.items():
        keys.append(k)
        values.append(v)
    
    
    return keys, values

# %%
keys, values = getItemsDict(d[0])

# %%
data = {"Nome": keys[1:], "Situação": values[1:], "Turma": values[0], "Data": "03/05/2021"}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                    Nome Situação                        Turma  \
# 0                Ana Julia Duarte Porto        N  Informática Básica 1º ano B
# 1       Antônio Henrique Pereira Santos        N  Informática Básica 1º ano B
# 2             Breno Ryan Costa da Silva        N  Informática Básica 1º ano B
# 3      Bruna Ariardyne de Souza Barbosa        N  Informática Básica 1º ano B
# 4          Cristiana dos Santos Pereira        F  Informática Básica 1º ano B
# 5             Daniele Ezequiel de Jesus        F  Informática Básica 1º ano B
# 6           Ellen Brenda Alves da Silva        F  Informática Básica 1º ano B
# 7   Emanuelle Beatriz da Silva Venâncio        F  Informática Básica 1º ano B
# 8       Gabriela do Nascimento Monteiro        P  Informática Básica 1º ano B
# 9              Gisele de Souza Mendonca        P  Informática Básica 1º ano B
# 10      Jefferson Breno Feitosa de Lima        P  Informática Básica 1º ano B
# ...
